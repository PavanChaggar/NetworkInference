# %%
import numpy as np
import networkx as nx
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from networkx.generators.random_graphs import gnp_random_graph
from matplotlib import animation

# %%
coord_path = '/home/chaggar/Documents/mbmgroup-refs/Data/mni_coordinates/mni-parcellation-scale1_coordinates.csv'

# %%
nodes = pd.read_csv(coord_path)

# %%
n = len(coords)

# %%
g = nx.random_geometric_graph(n, 0.5)

# %%
import plotly.graph_objs as go

coord_path = '/home/chaggar/Documents/mbmgroup-refs/Data/mni_coordinates/mni-parcellation-scale5_coordinates.csv'

coords = np.genfromtxt(coord_path, delimiter=',')

x, y, z = coords[:,0], coords[:,1], coords[:,2]

trace1=go.Scatter3d(x=x,
               y=y,
               z=z,
               mode='lines',
               line=dict(color='rgb(125,125,125)', width=5),
               hoverinfo='none'
               )

trace2=go.Scatter3d(x=x,
               y=y,
               z=z,
               mode='markers',
               name='actors',
               marker=dict(symbol='circle',
                             size=6,
                             #color=nodes.ID,
                             colorscale='Viridis',
                             line=dict(color='rgb(50,50,50)', width=0.5)
                             ),
               #text=nodes.ID,
               hoverinfo='text'
               )

axis=dict(showbackground=False,
          showline=False,
          zeroline=False,
          showgrid=False,
          showticklabels=False,
          title=''
          )

layout = go.Layout(
         title="Connectome",
         width=1000
         ,
         height=500,
         showlegend=False,
         scene=dict(
             xaxis=dict(axis),
             yaxis=dict(axis),
             zaxis=dict(axis),
        ),
     margin=dict(
        t=100
    ),
    hovermode='closest',
     )

# %%
import plotly as py
data=[trace1, trace2]
fig=go.Figure(data=trace2, layout=layout)
fig.show()
# Out:
# <div>
#
#
#             <div id="16377dc9-5bae-4106-886e-fa76819eba0d" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("16377dc9-5bae-4106-886e-fa76819eba0d")) {
#                     Plotly.newPlot(
#                         '16377dc9-5bae-4106-886e-fa76819eba0d',
#                         [{"hoverinfo": "text", "marker": {"colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "line": {"color": "rgb(50,50,50)", "width": 0.5}, "size": 6, "symbol": "circle"}, "mode": "markers", "name": "actors", "type": "scatter3d", "x": [15.568111455108365, 23.84905660377359, 33.266409266409255, 33.03811659192826, 38.65488372093023, 29.582345191040844, 22.12684989429175, 14.101408450704227, 13.318944844124701, 12.39873417721519, 21.946202531645568, 28.298555377207066, 33.62704309063892, 24.484774665042636, 12.963068181818187, 22.560000000000002, 11.74525745257452, 47.780582524271836, 41.26330150068213, 46.784105960264895, 38.92980561555075, 8.82236842105263, 9.947040498442362, 5.371720116618079, 4.383795309168448, 4.076376554174061, 5.07167832167832, 10.296728971962622, 5.241379310344826, 4.109557109557116, 8.153225806451616, 5.386194029850742, 4.422809457579973, 8.814504881450489, 34.65927977839334, 43.665876777251185, 41.18979591836734, 54.29411764705881, 52.45292014302743, 51.00895140664963, 46.48014888337468, 52.21604938271605, 54.148979591836735, 56.3112